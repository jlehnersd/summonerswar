# %%
import pandas as pd

# %%
df1 = pd.read_csv('monsters_20200517.csv')
df2 = pd.read_csv('monsters_20200524.csv')

# %%
df1.head()
# Out:
#          date      monster       family element                    acquired  \
# 0  2020-05-18    Hellhound    Hellhound    Fire   Unknown Scroll (tutorial)
# 1  2020-05-18        Fairy        Fairy   Water  Mystical Scroll (tutorial)
# 2  2020-05-18     Vagabond     Vagabond    Wind   Unknown Scroll (tutorial)
# 3  2020-05-18  Horned Frog  Horned Frog    Fire              Unknown Scroll
# 4  2020-05-18       Mimick       Mimick   Water              Unknown Scroll
#
#   build  id
# 0    no  -3
# 1    no  -2
# 2    no  -1
# 3   yes   1
# 4   yes   2

# %%
df2.head()
# Out:
#          date        monster         family element  \
# 0  2020-05-24     Rainbowmon     Rainbowmon   Light
# 1  2020-05-24   Surprise Box   Surprise Box    Fire
# 2  2020-05-24  Low Elemental  Low Elemental    Fire
# 3  2020-05-24        Sandman        Sandman   Water
# 4  2020-05-24          Slime          Slime    Fire
#
#                                             acquired build   id
# 0  6-star Evolution Reward (first Water Monster -...    no  346
# 1                                         Magic Shop   yes  347
# 2                                     Unknown Scroll    no  348
# 3                                     Unknown Scroll    no  349
# 4                                     Unknown Scroll    no  350

# %%
df1_new = df1['monster family element acquired build date id'.split()].copy()
df2_new = df2['monster family element acquired build date id'.split()].copy()

# %%
df1_new
# Out:
#             monster          family element  \
# 0         Hellhound       Hellhound    Fire
# 1             Fairy           Fairy   Water
# 2          Vagabond        Vagabond    Wind
# 3       Horned Frog     Horned Frog    Fire
# 4            Mimick          Mimick   Water
# ..              ...             ...     ...
# 343      Rainbowmon      Rainbowmon   Light
# 344          Mimick          Mimick    Wind
# 345   Skull Soldier   Skull Soldier    Wind
# 346  Monster Flower  Monster Flower    Fire
# 347   Skull Soldier   Skull Soldier   Water
#
#                                   acquired build        date   id
# 0                Unknown Scroll (tutorial)    no  2020-05-18   -3
# 1               Mystical Scroll (tutorial)    no  2020-05-18   -2
# 2                Unknown Scroll (tutorial)    no  2020-05-18   -1
# 3                           Unknown Scroll   yes  2020-05-18    1
# 4                           Unknown Scroll   yes  2020-05-18    2
# ...

# %%
df2_new
# Out:
#           monster         family element  \
# 0      Rainbowmon     Rainbowmon   Light
# 1    Surprise Box   Surprise Box    Fire
# 2   Low Elemental  Low Elemental    Fire
# 3         Sandman        Sandman   Water
# 4           Slime          Slime    Fire
# ..            ...            ...     ...
# 90     Rainbowmon     Rainbowmon   Light
# 91   Surprise Box   Surprise Box    Fire
# 92    Horned Frog    Horned Frog   Water
# 93  Forest Keeper  Forest Keeper   Water
# 94        Sandman        Sandman   Water
#
#                                              acquired build        date   id
# 0   6-star Evolution Reward (first Water Monster -...    no  2020-05-24  346
# 1                                          Magic Shop   yes  2020-05-24  347
# 2                                      Unknown Scroll    no  2020-05-24  348
# 3                                      Unknown Scroll    no  2020-05-24  349
# 4                                      Unknown Scroll    no  2020-05-24  350
# ...

# %%
df1_new.to_csv('monsters_20200517_new.csv', index=False)
df2_new.to_csv('monsters_20200524_new.csv', index=False)
